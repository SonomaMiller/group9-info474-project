# %%
import pandas as pd

df = pd.read_csv("washington_temperature.csv") # Replace csv name and column name
df['Washington 12-Month Period Average Temperature'] = pd.to_datetime(df['Washington 12-Month Period Average Temperature'],format='%Y%m').dt.strftime('%m-%Y')
print(df.head())
df.to_csv("temperature_clean.csv", index=False, header=True)
# Out:
#   Washington 12-Month Period Average Temperature  Value (Fahrenheit)
# 0                                        12-1895                45.2
# 1                                        01-1896                45.5
# 2                                        02-1896                45.6
# 3                                        03-1896                45.5
# 4                                        04-1896                45.2
